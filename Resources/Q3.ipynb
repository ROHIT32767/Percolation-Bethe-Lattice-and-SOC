# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample population data for states in India and USA
population_india = [199812341, 112374333, 104099452, 91276115, 72626809, 72147030, 68548437, 61095297, 60439692, 49577103, 41974218, 35003674, 33406061, 32988134, 31205576, 27743338, 25545198, 25351462, 10086292, 6864602, 3673917, 2966889, 2570390, 1978502, 1458545, 1383727, 1097206, 610577, 16787941, 12267032, 1247953, 1055450, 585764, 380581, 274000, 64473]
population_usa = [4849377, 736732, 6731484, 2966369, 38802500, 5355866, 3596677, 935614, 658893, 19893297, 10097343, 1419561, 1634464, 12880580, 6596855, 3107126, 2904021, 4413457, 4649676, 1330089, 5976407, 6745408, 9909877, 5457173, 2994079, 6063589, 1023579, 1881503, 2839099, 1326813, 8938175, 2085572, 19746227, 9943964, 739482, 11594163, 3878051, 3970239, 12787209, 1055173, 4832482, 853175, 6549352, 26956958, 2942902, 626562, 8326289, 7061530, 1850326, 5757564, 584153]

# Plot histograms
plt.figure(figsize=(12, 6))

# Plot for India
plt.subplot(1, 2, 1)
plt.hist(population_india, bins=10, color='blue', alpha=0.7, density=True, label='Data')
plt.title('Population Distribution in India')
plt.xlabel('Population')
plt.ylabel('Probability Density')

# Generate synthetic power-law data for India
power_law_exponent_india = -1.58  # Adjust this value as needed
x_india = np.linspace(min(population_india), max(population_india), 100)
y_india = x_india**power_law_exponent_india
plt.plot(x_india, y_india, color='red', linestyle='--', label=f'Power Law (exp={power_law_exponent_india})')

plt.legend()

# Plot for USA
plt.subplot(1, 2, 2)
plt.hist(population_usa, bins=10, color='green', alpha=0.7, density=True, label='Data')
plt.title('Population Distribution in USA')
plt.xlabel('Population')
plt.ylabel('Probability Density')

# Generate synthetic power-law data for USA
power_law_exponent_usa = -1.195  # Adjust this value as needed
x_usa = np.linspace(min(population_usa), max(population_usa), 100)
y_usa = x_usa**power_law_exponent_usa
plt.plot(x_usa, y_usa, color='red', linestyle='--', label=f'Power Law (exp={power_law_exponent_usa})')

plt.legend()

plt.tight_layout()
plt.show()
